# %% [markdown]
# ### Imports

# %%
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from transformer import Transformer

# %% [markdown]
# ### Artificial Time Series

# %%
sequence = np.sin(np.arange(0,100,1))
plt.plot(sequence)
plt.show()

# %% [markdown]
# ### Test Data Loader

# %%
from utils import load_src_trg

# %%
data_iter = load_src_trg(sequence.reshape(-1, 1), 10, 10, 2)

# %%
for src, trg, trg_y in data_iter:
    print(np.shape(src))
    print(src)
    print(trg)
    print(trg_y)
    break
# Out:
# torch.Size([2, 10, 1])
# tensor([[[ 0.0000],
#          [ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589],
#          [-0.2794],
#          [ 0.6570],
#          [ 0.9894],
#          [ 0.4121]],
#
#         [[ 0.8415],
#          [ 0.9093],
#          [ 0.1411],
#          [-0.7568],
#          [-0.9589],
#          [-0.2794],
#          [ 0.6570],
#          [ 0.9894],
#          [ 0.4121],
#          [-0.5440]]], dtype=torch.float64)
# tensor([[[ 0.4121],
#          [-0.5440],
#          [-1.0000],
#          [-0.5366],
#          [ 0.4202],
#          [ 0.9906],
#          [ 0.6503],
#          [-0.2879],
#          [-0.9614],
#          [-0.7510]],
#
#         [[-0.5440],
#          [-1.0000],
#          [-0.5366],
#          [ 0.4202],
#          [ 0.9906],
#          [ 0.6503],
#          [-0.2879],
#          [-0.9614],
#          [-0.7510],
#          [ 0.1499]]], dtype=torch.float64)
# tensor([[[-0.5440],
#          [-1.0000],
#          [-0.5366],
#          [ 0.4202],
#          [ 0.9906],
#          [ 0.6503],
#          [-0.2879],
#          [-0.9614],
#          [-0.7510],
#          [ 0.1499]],
#
#         [[-1.0000],
#          [-0.5366],
#          [ 0.4202],
#          [ 0.9906],
#          [ 0.6503],
#          [-0.2879],
#          [-0.9614],
#          [-0.7510],
#          [ 0.1499],
#          [ 0.9129]]], dtype=torch.float64)

# %% [markdown]
# ### Test Training

# %%
len(sequence)
# Out:
# 100

# %%
train_sequence = sequence[:90]
test_sequence = sequence[90:]

# %%
model = Transformer(pred_offset = 10,
                    input_size = 1,
                    output_size = 1,
                    max_seq_length = 10,
                    embedding_size = 10,
                    num_basic_encoders = 2,
                    num_atten_heads = 1,
                    num_basic_decoders = 2)

# %%
model.start_training(sequence=train_sequence.reshape(-1, 1),
                     loss=nn.MSELoss(),
                     metric=nn.MSELoss(),
                     epochs=40,
                     batch_size=32,
                     num_warmup_steps=100,
                     optimizer_params={'beta1':0.01, 'beta2': 0.01, 'epsilon': 0.1},
                     standardize=False,
                     verbose=True,
                     plot=True)

# %%
x = train_sequence[-10:].reshape(-1, 1)
y = test_sequence
y_hat = model.predict(x, False)
plt.plot(y)
plt.plot(y_hat)
plt.show()
